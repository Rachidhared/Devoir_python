# %% [markdown]
# Exercice 1 :

# %%
print("Entrez le nombre de lignes pour le plateau de jeu :")
nombreR = int(input())
print("Entrez le nombre de colonnes pour le plateau de jeu :")
nombreC = int(input())
print("Choisissez une ligne pour cacher le trésor (entre 1 et", nombreR, ") :")
tresorR = int(input())
if tresorR <= nombreR and tresorR > 0:
    bool = True
else:
    bool = False

while bool == False:
    print("Erreur, choisissez un emplacement valide (par exemple, un nombre entre 1 et", nombreR, ") :")
    tresorR = int(input())
    if tresorR <= nombreR and tresorR > 0:
        bool = True
    else:
        bool = False

print("Choisissez une colonne pour cacher le trésor (entre 1 et", nombreC, ") :")
tresorC = int(input())
if tresorC <= nombreC and tresorC > 0 :
   bool = True
else:
   bool = False
while bool == False:
    print("Erreur, choisissez un emplacement valide (par exemple, un nombre entre 1 et", nombreC, ") :")
    tresorC = int(input())
    if tresorC <= nombreC and tresorC > 0:
        bool = True
    else:
        bool = False

print("VOICI VOTRE PLATEAU DE JEU :")
j = 1
i = 1
while i <= nombreR:
  while j <= nombreC:
      if j == tresorC and i == tresorR:
       print("|T|", end="")
       j += 1
      else:
         print("|*|", end="")
         j +=  1

  i += 1
  print()
  j = 1
# Out:
# Entrez le nombre de lignes pour le plateau de jeu :
# 3
# Entrez le nombre de colonnes pour le plateau de jeu :
# 3
# Choisissez une ligne pour cacher le trésor (entre 1 et 3 ) :
# 5
# Erreur, choisissez un emplacement valide (par exemple, un nombre entre 1 et 3 ) :
# 2
# Choisissez une colonne pour cacher le trésor (entre 1 et 3 ) :
# 1
# VOICI VOTRE PLATEAU DE JEU :
# |*||*||*|
# |T||*||*|
# |*||*||*|

# %% [markdown]
# EXERCICE 2

# %%
def calculate_bmi(poids, taille):
 bool = False
 while bool == False:
      if poids > 0 and taille > 0:
       return poids / (taille ** 2)
       bool = True
       print("la taille et le poids ne peut pas etre nulle ")
       poids = float(input("Entrez votre poids en kilogrammes : "))
       taille = float(input("Entrez votre taille en mètres : "))
      else:
       bool = False

poids = float(input("Entrez votre poids en kilogrammes : "))
taille = float(input("Entrez votre taille en mètres : "))
imc = calculate_bmi(poids, taille)
if imc < 18.5:
    print("Insuffisance ponderal.")
elif 18.5 < imc < 25:
    print("Poids normal.")
elif 25 < imc < 30:
    print("Surpoids.")
else:
    print("Obésité.")
# Out:
# Entrez votre poids en kilogrammes : 110
# Entrez votre taille en mètres : 2
# Surpoids.
